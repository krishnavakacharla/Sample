# %%
words = {
  "హలో": "Hello",
  "శుభ సాయంత్రం": "Good Evening",
  "ధన్యవాదాలు": "Thank You",
  "సంతోషం": "Happiness",
  "కుమారుడు": "Boy",
  "కుమార్తె": "Girl",
  "పుస్తకం": "Book",
  "పాఠశాల": "School",
  "ప్రతి రోజు": "Every Day",
  "వేడి": "Hot",
  "చల్లటి": "Cold",
  "నీరు": "Water",
  "ఆకలి": "Hunger",
  "నిద్ర": "Sleep",
  "మిత్రుడు": "Friend",
  "స్నేహం": "Friendship",
  "వర్షం": "Rain",
  "నవ్వు": "Smile",
  "ఇల్లు": "House",
  "గడప": "Door",
  "అమ్మ": "Mother",
  "తల్లి": "Mother",
  "నాన్న": "Father",
  "తండ్రి": "Father",
  "అన్న": "Elder Brother",
  "అక్క": "Elder Sister",
  "పిల్ల": "Child",
  "ఆగస్టు": "August",
  "జూన్": "June",
  "జనవరి": "January",
  "విక్రయము": "Sale",
  "బడి": "School",
  "ఆహారం": "Food",
  "వంట": "Cooking",
  "పసిపిల్ల": "Baby",
  "వేగంగా": "Fast",
  "నెమ్మదిగా": "Slow",
  "ప్రేమ": "Love",
  "పలుకుబడి": "Speech",
  "భాష": "Language",
  "పదము": "Word",
  "పరీక్ష": "Exam",
  "గురువు": "Teacher",
  "విద్యార్థి": "Student",
  "సూర్యుడు": "Sun",
  "నక్షత్రం": "Star",
  "చంద్రుడు": "Moon",
  "ఆకాశం": "Sky",
  "పగలు": "Daytime",
  "రాత్రి": "Night",
  "కన్ను": "Eye",
  "నాకు": "To Me",
  "నీకు": "To You",
  "ఆట": "Game",
  "పరుగెత్తు": "Run",
  "వెళ్ళు": "Go",
  "వచ్చింది": "Came",
  "కూరగాయ": "Vegetable",
  "పండ్లు": "Fruits",
  "తిన్నాను": "Ate",
  "కలిసి": "Together",
  "తెరకు": "Open",
  "మూసు": "Close",
  "వారు": "They",
  "ఆత్మ": "Soul",
  "పని": "Work",
  "రేపు": "Tomorrow",
  "నేడు": "Today",
  "నిన్న": "Yesterday",
  "వేగం": "Speed",
  "తరుగు": "Clean",
  "పొట్టు": "Dirty",
  "పూజ": "Prayer",
  "ఆశీర్వాదం": "Blessing",
  "సమయం": "Time",
  "స్థలం": "Place",
  "స్నానం": "Bath",
  "పుస్తకాలు": "Books",
  "కార్యాలయం": "Office",
  "సహాయం": "Help",
  "పని చేయు": "Work",
  "విద్య": "Education",
  "నడి": "Walk",
  "ఎత్తు": "Height",
  "బలం": "Strength",
  "అందం": "Beauty",
  "బంధం": "Relation",
  "సంతానం": "Child",
  "గజం": "Elephant",
  "పిల్లి": "Cat",
  "కుక్క": "Dog",
  "చిలుక": "Parrot",
  "నక్క": "Fox",
  "గొర్రె": "Sheep",
  "పంది": "Pig",
  "పసుపు": "Turmeric",
  "ఉప్పు": "Salt",
  "చక్కెర": "Sugar",
  "నూనె": "Oil",
  "చలి": "Cold",
  "వేడిగా": "Warm",
  "మంచు": "Snow",
  "గాలి": "Wind",
  "వేడి కofa": "Heat",
  "వర్షం పడుతుంది": "It is Raining",
  "మేఘాలు": "Clouds",
  "వృక్షం": "Tree",
  "పూలు": "Flowers",
  "చెట్టు": "Tree",
  "పక్షి": "Bird",
  "జంతువు": "Animal",
  "కార్యము": "Work",
  "పథం": "Path",
  "వేగము": "Speed",
  "మైదానం": "Ground",
  "వీధి": "Street",
  "సड़क": "Road",
  "పుస్తకం చదవు": "Read Book",
  "కంప్యూటర్": "Computer",
  "ఫోన్": "Phone",
  "రేకులు": "Leaves",
  "మొక్క": "Plant",
  "నది": "River",
  "సముద్రం": "Sea",
  "గంగా": "Ganges",
  "ఆకుపచ్చ": "Green",
  "నలుపు": "Black",
  "తెలుపు": "White",
  "ఎరుపు": "Red",
  "నీలం": "Blue",
  "పసుపు": "Yellow",
  "పింక్": "Pink",
  "నాకు నచ్చింది": "I Like",
  "నాకు ఇష్టం లేదు": "I Don’t Like",
  "తినడం": "Eating",
  "పోతున్నాను": "Going",
  "నిలువు": "Stop",
  "ప్రారంభం": "Start",
  "ఆగు": "Stop",
  "వెళ్ళు": "Go",
  "క్రొత్త": "New",
  "పాత": "Old",
  "చిన్న": "Small",
  "పెద్ద": "Big",
  "ఎక్కువ": "More",
  "తక్కువ": "Less",
  "మధ్య": "Middle",
  "ఇది": "This",
  "అది": "That",
  "వైపు": "Towards",
  "వెనుక": "Back",
  "ముందు": "Front",
  "కుడి": "Right",
  "ఎడమ": "Left",
  "అప్పు": "Debt",
  "సంపాదించు": "Earn",
  "కలలు": "Dreams",
  "సంకల్పం": "Determination",
  "విజయం": "Success",
  "విఫలం": "Failure",
  "అడుగు": "Step",
  "ప్రయత్నం": "Effort",
  "శ్రమ": "Hard Work",
  "వేదన": "Pain",
  "సంతోషించు": "Be Happy",
  "కంప్యూటర్ శాస్త్రం": "Computer Science",
  "సాంకేతిక విజ్ఞానం": "Technology",
  "అవకాశం": "Opportunity",
  "సమస్య": "Problem",
  "సమాధానం": "Solution",
  "నేత": "Leader",
  "జనం": "People",
  "దేశం": "Country",
  "సాహసం": "Adventure",
  "కథ": "Story",
  "చిత్రం": "Picture",
  "సినిమా": "Movie",
  "నాటకం": "Drama",
  "సంగీతం": "Music",
  "కవిత్వం": "Poetry",
  "లేఖ": "Letter",
  "పత్రిక": "Newspaper",
  "రాజకీయాలు": "Politics",
  "ఆర్థికము": "Economy",
  "పరిశీలన": "Observation",
  "అభిప్రాయం": "Opinion",
  "సమావేశం": "Meeting",
  "పరస్పరం": "Mutual",
  "సంపర్కం": "Contact",
  "స్నేహితులు": "Friends",
  "కుటుంబం": "Family",
  "సమస్యలు": "Problems",
  "పరిష్కారం": "Solution",
  "స్వప్నం": "Dream",
  "భవిష్యత్తు": "Future",
  "గతం": "Past",
  "ప్రస్తుతం": "Present",
  "సంక్షిప్తం": "Summary",
  "పరిచయం": "Introduction",
  "వివరణ": "Explanation",
  "సూచన": "Hint",
  "ప్రతిస్పందన": "Response",
  "పలుకుబడి": "Communication",
  "వివాదం": "Argument",
  "న్యాయం": "Justice",
  "అసత్యం": "Falsehood",
  "వాస్తవం": "Truth",
  "శాంతి": "Peace",
  "సమర": "War",
  "విదేశం": "Foreign",
  "అంతర్జాతీయ": "International",
  "దేశీయ": "Local",
  "పరిశ్రమ": "Industry",
  "వ్యవసాయం": "Agriculture",
  "సాంకేతికత": "Technology",
  "పరిశోధన": "Research",
  "శాస్త్రం": "Science",
  "సాహిత్యం": "Literature",
  "సంస్కృతి": "Culture",
  "చరిత్ర": "History",
  "భూగోళం": "Geography",
  "సమాజం": "Society",
  "ఆరోగ్యము": "Health",
  "వైద్యం": "Medicine",
  "ఉద్యోగం": "Job",
  "పని": "Work",
  "ధనం": "Money",
  "ధనవంతుడు": "Rich",
  "పేద": "Poor",
  "సంతోషం": "Happiness",
  "దుఃఖం": "Sadness"
}

# %%
inp = input("Enter the word : ")

# %%
if inp in words:
    print(words[inp])
